# %% [markdown]
# # machine_learning_assignments2

# %% [raw]
# 1. What is the concept of human learning? Please give two examples.
# answer:humans possess the ability to learn where learning is the process of aquiring skills,knowledge,behaviour,values,preferences,etc.e.g-singing,playing sports.
#
#
#
#
# 2. What different forms of human learning are there? Are there any machine learning equivalents?
# answer:1)motor learning
#        2)verbal learning
#        3)concept learning
#        4)discrimination learning
#        5)learning of principles
#        6)problem solving
#        7)attitude learning
# there are several which are equivalent to human learning which are verbal learning,concept learning,problem solving,discrimination learning,learning of principles.
#
#
#
#
# 3. What is machine learning, and how does it work? What are the key responsibilities of machine
# learning?
# answer:machine learning is the capability of machine to imitate human intlligence.
# the key responsibilities are 1)to define the problem
#                              2)aquire and prepare data
#                              3)train and evaluate model
#                              4)deploy model
#
#
#
#
# 4. Define the terms "penalty" and "reward" in the context of reinforcement learning.
# answer:an agent in reinforcement learning is rewarded(reward) for correct steps and punished(penalty) for incorrect steps and that is how training is done.
#
#
#
#
# 5. Explain the term "learning as a search"?
# answer:main goal of this search is to find hypothesis that best fits the training examples.
#
#
#
#
# 6. What are the various goals of machine learning? What is the relationship between these and
# human learning?
# answer: goals of machine learning is to 1)make computers intlligent
#                                         2)follow human learning process through computational model.
#                                         3)to explore new learning methods.
#
#
#                                                                                                                                7. Illustrate the various elements of machine learning using a real-life illustration.
# answer:1)supervised learning-It is branch of machine learning which is used for prediction using labelled input data.here machine learns using trining set.  (e.g.based on prior knowledge wether prediction apps predict the wether.)
#
#        2)unsupervised learning-It is branch of machine learning which is used for analysis,here input data is unlabelled.(e.g.when we do not have any prior knowledge of people in a party and we divide them on the basis of various aspects )
#
#        3)reinforcement learning-in this machine learns how to optimally perform in a certain environment.here machine is made to learn using the concept of reward and penelty.it is a constant learning of decision making. (e.g.self driving cars)
#
#
#
#
# 8. Provide an example of the abstraction method.
# answer:Abstraction in about preserving better ideas and applying those ideas further for better problem solving.
# e.g.classify patterns by descrete labels.
#
#
#
#
# 9. What is the concept of generalization? What function does it play in the machine learning
# process?
# answer:generalization is the ability of machine to adapt the new unseen data and forecast,the distribution of unseen data is similar to the distribution of trained data;the function of generalization is to make predictions.
#
#
#
#
# 10.What is classification, exactly? What are the main distinctions between classification and regression?
# answer:classification is a technique under supervised ML.here the data is classified according to the labels which are already known.
# the difference between classification and regression:
# classification model predict according to class label,it deals with the categorical data.whereas,
# regression model deals with the continous data and predict in the form of a quantity.
#
#
#
#
# 11. What is regression, and how does it work? Give an example of a real-world problem that was
# solved using regression.
# answer:regression is a ML model which falls under supervised learning,it predicts the relationship between dependent variable with the independent variable.e.g. finding out the effect of investing on TV,newspaper,radio advertisement on the sales.
#
#
#
#
# 12. Describe the clustering mechanism in detail.
# answer:clustering is an unsupervised machine learning technique which is use to cluster the data having similar properties,other clusters formed would have different properties. in clustering we do not have any previous knowledge about the data labels using which it can be grouped.
#
#
#
#
# 13. Make brief observations on two of the following topics:
# answer:
# ii. Studying under supervision-in machine learning studying under supervision is considered as supervised learning.here machine makes prediction using the trained dataset.machine is trained in such a way that when there in new unseen data with distribution similar to as that of trained data is fed into the model it gives prediction.
#
# iii. Studying without supervision-in machine learning studying without any supervision is considered as unsupervised learning. here the unsupervised ML models does the analysis of the data and not the prediction.there is no use of trained dataset in this case also the input data is not labelled beforehand.
