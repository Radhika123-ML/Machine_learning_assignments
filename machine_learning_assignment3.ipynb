# %% [markdown]
# # machine_learning_assignment3

# %% [raw]
# 1.Explain the term machine learning, and how does it work? Explain two machine learning
# applications in the business world. What are some of the ethical concerns that machine learning
# applications could raise?
# answer:ML comes under AI domain,it is the ability of the computer to replicate human intlligence by learning through data,here machine learns without human interventions.
# application of ML in business world:
# 1)sales prediction
# 2)fraud prediction
# 3)customer recommendation.
# 4)chatbots for interaction,etc
#
# ethical concerns by ML:ML model can be biased and discriminate,can cause threat to privacy,etc
#
#
#
#
#
# 2. Describe the process of human learning:
# i. Under the supervision of experts
#
# ii. With the assistance of experts in an indirect manner
#
# iii. Self-education
# answer:
# i. Under the supervision of experts:for an example human learning to play guitar under the supervision of an instrumentalist is a good example of human learning under the supervision of expert.
#
# ii. With the assistance of experts in an indirect manner:for an example a kid learning how to speak by observing people talking to each other.
#
# iii. Self-education:practicing sprints everyday and improving gradually is an example of self education.
#
#
#
#
#
# 3. Provide a few examples of various types of machine learning.
# answer:
# 1)supervised learning example:sentiment analysis of tweets,image segmentation,sales prediction,etc
#
# 2)unsupervised learning examples:fraud detection,clustering analysis,anomaly detection.
#
# 3)reinforcement learning:self driving cars,robots performing task.
#
#
#
#
#
# 4. Examine the various forms of machine learning.
# answer:1)supervised learning-It is branch of machine learning which is used for prediction using labelled input data.here machine learns using trining set.  (e.g.based on prior knowledge wether prediction apps predict the wether.)
#
#        2)unsupervised learning-It is branch of machine learning which is used for analysis,here input data is unlabelled.(e.g.when we do not have any prior knowledge of people in a party and we divide them on the basis of various aspects )
#
#        3)reinforcement learning-in this machine learns how to optimally perform in a certain environment.here machine is made to learn using the concept of reward and penelty.it is a constant learning of decision making. (e.g.self driving cars)
#
#
#
#
#
# 5. Can you explain what a well-posed learning problem is? Explain the main characteristics that must
# be present to identify a learning problem properly.
# answer:when the machine learns from the experience with reference to some task and some performance measure,if its performance increases with experience.Any problem can be segregated as well-posed learning problem if it has three traits – Task, Performance and Experience.
#
#
#
#
#
# 6. Is machine learning capable of solving all problems? Give a detailed explanation of your answer.
# answer:machine learning is capable of performing very well in so many cases,but there are few areas where ML is questionable.
# 1)Reasoning ability:for an example ML can seggeregate apples from oranges,but it wont be able to explain why the fruit is an apple or  why the fruit is an orange.
#
# 2)not able to understand the context:in case of NLP machines are able to recognise speech.but the problem is that the machine is fed by symbols a computer programs or algorithms grasp the idea merely by ‘symbols’ rather than the context given
#
#
#
#
#
# 7. What are the various methods and technologies for solving machine learning problems? Any two
# of them should be defined in detail.
# answer:The Various Methods used in Machine Learning Problems are:
#                         Regression
#                         Classification
#                         Clustering
#                         Dimensionality Reductio
#                         Ensemble Methods
#                         Neural Network
#                         Deep Learning
#                         Transfer Learning
#                         Reinforcement Learning
#                         Natural Language Processing
#                         Word Embeddings.
# 1)clustering:clustering is an unsupervised machine learning technique which is use to cluster the data having similar properties,other clusters formed would have different properties. in clustering we do not have any previous knowledge about the data labels using which it can be grouped.
#
# 2)regression:regression is a ML model which falls under supervised learning,it predicts the relationship between dependent variable with the independent variable.e.g. finding out the effect of investing on TV,newspaper,radio advertisement on the sales.
#
# technologies used in ML are:Scikit Learn
#                             Pytorch
#                             Tensorflow
#                             Keras
#                             Python.
#
# Scikit Learn: Scikit-learn (Sklearn) is the most useful and robust library for machine learning in Python. It provides a selection of efficient tools for machine learning and statistical modeling including classification, Regression, clustering and dimensionality reduction via a consistence interface in Python.
#
# Tensorflow: It is a open source artificial intelligence library, Using data flow graphs to build models. It allows developers to create large-scale neural networks with many layers. TensorFlow is mainly used for: Classification, Perception, Understanding, Discovering, Prediction and Creation
#
#
#
#
#
# 8. Can you explain the various forms of supervised learning? Explain each one with an example
# application.
# answer:there are two types of supervised learning,classification and regression.
#
# classification:classification is a technique under supervised ML.here the data is classified according to the labels which are already known.it deals with the categorical data.e.g.to classify loan defaulters.
#
# regression:regression is a ML model which falls under supervised learning,it predicts the relationship between dependent variable with the independent variable.e.g. finding out the effect of investing on TV,newspaper,radio advertisement on the sales.
#
#
#
#
#
# 9. What is the difference between supervised and unsupervised learning? With a sample application
# in each region, explain the differences.
# answer:
# 1)supervised learning-It is branch of machine learning which is used for prediction using labelled input data.here machine learns using trining set.  (e.g.based on prior knowledge wether prediction apps predict the wether.)
#
#        2)unsupervised learning-It is branch of machine learning which is used for analysis,here input data is unlabelled.(e.g.when we do not have any prior knowledge of people in a party and we divide them on the basis of various aspects )
#
#
#
#
#
# 10. Describe the machine learning process in depth.
#
#
# a. Make brief notes on any two of the following:
#
# i. MATLAB is one of the most widely used programming languages.
#
# ii. Deep learning applications in healthcare
#
# iii. Study of the market basket
#
# iv. Linear regression (simple)
#
# answer:in a dataset with rows and columns, where rows are the observation and columns are the features,we make required rectification in the data like handling the missing value,ranking the categorical data,etc followed by data visualisation and feature selection.after rectification and feature selection at the very beginning dataset is made to split into two parts in the ratio generally 80:20,where 80 is the train data and 20 is the test data.secondly a model is created according to the problem statement and the then the model is then trained using the training data.it is made sure that the model's accuracy is good.with the confirmation the model is ready to get tested using the test data.this will tell wether the model is able to generalise the data or not.
#
#  Linear regression (simple):Linear Regression models describe the relationship between dependent and independent variable by fitting a line to the observed data. Linear regression models use a straight line, while logistic and nonlinear regression models use a curved line. Regression allows you to estimate how a dependent variable changes as the independent variable(s) change,linear regression is also used for feature selection.
#
# MATLAB is one of the most widely used programming languages:MATLAB is a programming laguage widely prefered by engineers ans scientists. MATLAB is very easy compared to any other programming language because of its command line interface, its very easy to make computational codes here.Several mathematical operations that work on arrays or matrices are built-in to the Matlab environment.It is benificial for those who are not prefessional programmers.
#
# 11. Make a comparison between:-
#
# 1. Generalization and abstraction
#
# 2. Learning that is guided and unsupervised
#
# 3. Regression and classification
#
# answer:
# 1)Abstraction in about preserving better ideas and applying those ideas further for better problem solving.
# e.g.classify patterns by descrete labels.
#     generalization is the ability of machine to adapt the new unseen data and forecast,the distribution of unseen data is similar to the distribution of trained data;the function of generalization is to make predictions.
#
# 2)In machine learning studying under supervision is considered as supervised learning.here machine makes prediction using the trained dataset.machine is trained in such a way that when there in new unseen data with distribution similar to as that of trained data is fed into the model it gives prediction.
#      In machine learning studying without any supervision is considered as unsupervised learning. here the unsupervised ML models does the analysis of the data and not the prediction.there is no use of trained dataset in this case also the input data is not labelled beforehand.
#
# 3)classification is a technique under supervised ML.here the data is classified according to the labels which are already known.classification model predict according to class label,it deals with the categorical data.whereas,
#       Regression predicts the relationship between dependent variable with the independent variable regression model deals with the continous data and predict in the form of a quantity.
