# %% [markdown]
# 1.  **Given X be a discrete random variable with the following PMF**
#
# <img src="attachment:media/image1.png" style="width:1.9in;height:1.5in" alt="images" />
#
# **1. Find the range RX of the random variable X.**
#
# **2. Find P(X ≤ 0.5)**
#
# **3. Find P(0.25\<X\<0.75)**
#
# > **4. P(X = 0.2\|X\<0.6)**
# >
# > Based on the provided probability mass function (PMF) for the discrete
# > random variable X, we can determine the range RX, as well as calculate
# > the probabilities P(X≤0.5), P(0.25\<X\<0.75), and P(X=0.2\|X\<0.6).
# > Let's calculate each of these:
# >
# > **1. Range RX:** The range of X is the set of all possible values that
# > X can take. Looking at the PMF, we can identify the following possible
# > values: 0, 0.2, 0.4, 0.5, 0.8, and 1. Therefore, the range RX of the
# > random variable X is {0, 0.2, 0.4, 0.5, 0.8, 1}.
# >
# > **2. P(X≤0.5):** This represents the probability that X is less than
# > or equal to 0.5. From the PMF, we see that P(X=0) = 0.1, P(X=0.2) =
# > 0.2, and P(X=0.4) = 0.2. Summing up these probabilities, we have
# > P(X≤0.5) = P(X=0) + P(X=0.2) + P(X=0.4) = 0.1 + 0.2 + 0.2 = 0.5.
# >
# > **3. P(0.25\<X\<0.75):** This represents the probability that X is
# > greater than 0.25 and less than 0.75. The only value within this range
# > according to the PMF is X=0.4, with a probability of 0.2. Therefore,
# > P(0.25\<X\<0.75) = P(X=0.4) = 0.2.
# >
# > **4. P(X=0.2\|X\<0.6):** This represents the conditional probability
# > that X is equal to 0.2, given that X is less than 0.6. To calculate
# > this, we need to find the probability of X being both 0.2 and less
# > than 0.6, and divide it by the probability of X being less than 0.6.
# > From the PMF, we have P(X=0.2) = 0.2 and P(X\<0.6) = P(X=0) +
# > P(X=0.2) + P(X=0.4) = 0.1 + 0.2 + 0.2 = 0.5. Therefore,
# > P(X=0.2\|X\<0.6) = P(X=0.2 and X\<0.6) / P(X\<0.6) = P(X=0.2) /
# > P(X\<0.6) = 0.2 / 0.5 = 0.4.
# >
# > **To summarize:**
#
# 1.  **Range RX:** {0, 0.2, 0.4, 0.5, 0.8, 1}
#
# 2.  **P(X≤0.5):** 0.5
#
# 3.  **P(0.25\<X\<0.75**): 0.2
#
# 4.  **P(X=0.2\|X\<0.6):** 0.4
#
# <!-- -->
#
# 1.  **Two equal and fair dice are rolled, and we observed two numbers X
#     and Y.**
#
# **1. Find RX, RY, and the PMFs of X and Y.**
#
# **2. Find P(X = 2,Y = 6).**
#
# **3. Find P(X>3\|Y = 2).**
#
# **4. If Z = X + Y. Find the range and PMF of Z.**
#
# **5. Find P(X = 4\|Z = 8).**
#
# **Sure! Let's solve each of the questions step by step:**
#
# **1. Find RX, RY, and the PMFs of X and Y:**
#
# Since two fair dice are rolled, the possible outcomes for each die range
# from 1 to 6. Therefore, the range of X and Y is {1, 2, 3, 4, 5, 6}.
#
# The probability mass function (PMF) for X and Y in this case is the same
# because both dice are fair and independent. Each outcome has an equal
# probability of 1/36. **Therefore, the PMFs of X and Y are:**
#
# **PMF of X: P(X = x) = 1/36 for x in {1, 2, 3, 4, 5, 6}**
#
# **PMF of Y: P(Y = y) = 1/36 for y in {1, 2, 3, 4, 5, 6}**
#
# **2. Find P(X = 2, Y = 6):**
#
# Since X represents the outcome of the first die and Y represents the
# outcome of the second die, the probability of getting X = 2 and Y = 6 is
# the probability of both events occurring simultaneously.
#
# **P(X = 2, Y = 6) = P(X = 2) \* P(Y = 6) = (1/36) \* (1/36) = 1/1296**
#
# **3. Find P(X \> 3 \| Y = 2):**
#
# Given that Y = 2, we are only considering the cases where the outcome of
# the second die is 2. In such cases, X can only be greater than 3 if the
# outcome of the first die is 4, 5, or 6.
#
# **P(X \> 3 \| Y = 2) = P(X \> 3 and Y = 2) / P(Y = 2)**
#
# To find P(X \> 3 and Y = 2), we consider the case where X is 4, 5, or 6
# and Y is 2. Since X and Y are independent, we multiply their individual
# probabilities:
#
# **P(X \> 3 and Y = 2) = P(X = 4) \* P(Y = 2) + P(X = 5) \* P(Y = 2) +
# P(X = 6) \* P(Y = 2) = (1/36) \* (1/36) + (1/36) \* (1/36) + (1/36) \*
# (1/36) = 3/1296**
#
# **Therefore,**
#
# **P(X \> 3 \| Y = 2) = (3/1296) / (1/36) = 3/36 = 1/12**
#
# **4. If Z = X + Y, find the range and PMF of Z:**
#
# The range of Z will be the sum of all possible outcomes of X and Y.
# Since X and Y range from 1 to 6, Z will range from 2 to 12.
#
# The PMF of Z can be obtained by considering all possible combinations of
# X and Y and summing up the probabilities where the sum equals Z.
#
# **PMF of Z:**
#
# **P(Z = z) = P(X + Y = z) = Sum of P(X = x, Y = z - x) for all x in {1,
# 2, 3, 4, 5, 6}**
#
# **For example,** P(Z = 4) = P(X = 1, Y = 3) + P(X = 2, Y = 2) + P(X = 3,
# Y = 1) = (1/
#
# **36) + (1/36) + (1/36) = 3/36 = 1/12**
#
# **5. Find P(X = 4 \| Z = 8):**
#
# To find this probability, we need to consider the cases where X = 4 and
# Z = 8. We divide the probability of X = 4 and Z = 8 by the probability
# of Z = 8.
#
# **P(X = 4 \| Z = 8) = P(X = 4 and Z = 8) / P(Z = 8)**
#
# To find P(X = 4 and Z = 8), we need to find the cases where X = 4 and Y
# = 8 - X = 4. Therefore, we calculate:
#
# **P(X = 4 and Z = 8) = P(X = 4, Y = 4) = (1/36)**
#
# To find P(Z = 8), we sum up the probabilities of all cases where X + Y =
# 8:
#
# **P(Z = 8) = P(X = 2, Y = 6) + P(X = 3, Y = 5) + P(X = 4, Y = 4) + P(X =
# 5, Y = 3) + P(X = 6, Y = 2) = 5/36**
#
# **Therefore,**
#
# **P(X = 4 \| Z = 8) = (1/36) / (5/36) = 1/5**
#
# 1.  **In an exam, there were 20 multiple-choice questions. Each question
#     had 44 possible options. A student knew the answer to 10 questions,
#     but the other 10 questions were unknown to him, and he chose answers
#     randomly. If the student X's score is equal to the total number of
#     correct answers, then find out the PMF of X. What is P(X>15)?**
#
# To find the probability mass function (PMF) of X, which represents the
# score of the student, we need to consider the number of correct answers
# out of the 10 unknown questions. Since the student knew the answer to 10
# questions, we can determine the number of correct answers to the unknown
# questions as follows:
#
# Let's define X as the number of correct answers out of the unknown 10
# questions. Since each question has 44 possible options, the probability
# of randomly selecting the correct answer to a single question is 1/44.
#
# **The PMF of X can be calculated using the binomial probability
# formula:**
#
# PMF of X: P(X = x) = C(n, x) \* p^x \* (1-p)^(n-x)
#
# **Where:**
#
# \- n is the number of trials (10 in this case)
#
# \- x is the number of successes (number of correct answers out of the
# unknown 10 questions)
#
# \- p is the probability of success (1/44)
#
# **We can calculate the PMF of X for each possible value of x (from 0 to
# 10) using the formula:**
#
# P(X = x) = C(10, x) \* (1/44)^x \* (1 - 1/44)^(10 - x)
#
# **Here's the PMF of X:**
#
# x \| P(X = x)
#
# ---------------------
#
# 0 \| C(10, 0) \* (1/44)^0 \* (1 - 1/44)^(10 - 0)
#
# 1 \| C(10, 1) \* (1/44)^1 \* (1 - 1/44)^(10 - 1)
#
# 2 \| C(10, 2) \* (1/44)^2 \* (1 - 1/44)^(10 - 2)
#
# 3 \| C(10, 3) \* (1/44)^3 \* (1 - 1/44)^(10 - 3)
#
# 4 \| C(10, 4) \* (1/44)^4 \* (1 - 1/44)^(10 - 4)
#
# 5 \| C(10, 5) \* (1/44)^5 \* (1 - 1/44)^(10 - 5)
#
# 6 \| C(10, 6) \* (1/44)^6 \* (1 - 1/44)^(10 - 6)
#
# 7 \| C(10, 7) \* (1/44)^7 \* (1 - 1/44)^(10 - 7)
#
# 8 \| C(10, 8) \* (1/44)^8 \* (1 - 1/44)^(10 - 8)
#
# 9 \| C(10, 9) \* (1/44)^9 \* (1 - 1/44)^(10 - 9)
#
# 10 \| C(10, 10) \* (1/44)^10 \* (1 - 1/44)^(10 - 10)
#
# **To find P(X \> 15), we sum up the probabilities for X greater than
# 15:**
#
# P(X \> 15) = P(X = 16) + P(X = 17) + P(X = 18) + P(X = 19) + P(X = 20)
#
# Please note that since X represents the score, which is the total number
# of correct answers, the probability of X exceeding 15 is essentially 0
# because the student only answered 10 questions. Therefore, P(X \> 15) is
# equal to 0.
#
# 1.  **The number of students arriving at a college between a time
#     interval is a Poisson random variable. On average, 10 students
#     arrive per hour. Let Y be the number of students arriving from 10 am
#     to 11:30 am. What is P(10\<Y≤15)?**
#
# To find the probability P(10 \< Y ≤ 15), where Y represents the number
# of students arriving between 10 am and 11:30 am, we need to use the
# properties of a Poisson distribution.
#
# **In this case, the average number of students arriving per hour is 10.
# However, we are interested in the number of students arriving between 10
# am and 11:30 am, which corresponds to a time interval of 1.5 hours.**
#
# The Poisson distribution can be used to calculate the probability of
# observing a certain number of events within a specific time interval,
# given the average rate of occurrence.
#
# **The probability mass function (PMF) of the Poisson distribution is
# given by:**
#
# P(Y = k) = (e^(-λ) \* λ^k) / k!
#
# **Where:**
#
# -   Y is the random variable representing the number of events (in this
#     case, the number of students arriving between 10 am and 11:30 am)
#
# -   λ is the average rate of occurrence (10 students per hour)
#
# -   k is the number of events we are interested in (in this case, 10,
#     11, 12, 13, 14, or 15)
#
# **To find P(10 \< Y ≤ 15), we sum the probabilities of Y being each
# value from 11 to 15:**
#
# P(10 \< Y ≤ 15) = P(Y = 11) + P(Y = 12) + P(Y = 13) + P(Y = 14) + P(Y =
# 15)
#
# **Using the PMF formula, we can substitute the values:**
#
# P(10 \< Y ≤ 15) = (e^(-λ) \* λ^11) / 11! + (e^(-λ) \* λ^12) / 12! +
# (e^(-λ) \* λ^13) / 13! + (e^(-λ) \* λ^14) / 14! + (e^(-λ) \* λ^15) / 15!
#
# **Substituting λ = 10 \* 1.5 = 15 (since the average rate is 10 students
# per hour and the time interval is 1.5 hours), we have:**
#
# P(10 \< Y ≤ 15) = (e^(-15) \* 15^11) / 11! + (e^(-15) \* 15^12) / 12! +
# (e^(-15) \* 15^13) / 13! + (e^(-15) \* 15^14) / 14! + (e^(-15) \* 15^15)
# / 15!
#
# Calculating this expression will give you the probability P(10 \< Y ≤
# 15) of the number of students arriving between 10 am and 11:30 am being
# greater than 10 and less than or equal to 15.
#
# 1.  **Two independent random variables, X and Y,are given such that
#     X\~Poisson(α) and Y\~Poisson(β). State a new random variable as Z =
#     X + Y. Find out the PMF of Z.**
#
# To find the probability mass function (PMF) of the new random variable
# Z, which is defined as the sum of two independent random variables X and
# Y, both following Poisson distributions, we can use the properties of
# the Poisson distribution.
#
# Given that X follows a Poisson distribution with parameter α and Y
# follows a Poisson distribution with parameter β, the PMF of Z can be
# found by convolving the PMFs of X and Y.
#
# **The PMF of Z, denoted as P(Z = z), is given by:**
#
# P(Z = z) = ∑\[P(X = x) \* P(Y = z - x)\] for all possible values of x
#
# Since X and Y are independent, their probabilities multiply together.
#
# **Therefore, the PMF of Z can be written as:**
#
# P(Z = z) = ∑\[P(X = x) \* P(Y = z - x)\] for all possible values of x
#
# **Substituting the PMFs of the Poisson distributions for X and Y:**
#
# P(Z = z) = ∑\[(e^(-α) \* α^x / x!) \* (e^(-β) \* β^(z - x) / (z - x)!)\]
# for all possible values of x
#
# **Simplifying further, we have:**
#
# P(Z = z) = ∑\[(e^(-α) \* e^(-β) \* α^x \* β^(z - x)) / (x! \* (z -
# x)!)\] for all possible values of x
#
# **This expression represents the PMF of Z, where z is the desired value
# of the sum of X and Y.**
#
# Note that the summation should be taken over all possible values of x,
# which depend on the ranges of the Poisson distributions for X and Y.
#
# To obtain the specific values of the PMF, you would need to evaluate the
# summation for each value of z and the corresponding valid range of x.
#
# 1.  **There is a discrete random variable X with the pmf. **
#
# <img src="attachment:media/image2.png" style="width:4.375in;height:1.5in" alt="images" />
#
# **1. If we define a new random variable Y = (X + 1)2 then**
#
# **1. Find the range of Y.**
#
# **2. Find the pmf of Y.**
#
# To find the range and PMF of the random variable Y, defined as Y = (X +
# 1), we can use the given PMF of X and apply the transformation to
# determine the range and PMF of Y.
#
# **1. Finding the range of Y:**
#
# Since Y = (X + 1), the range of Y will be determined by the range of X,
# shifted by 1 unit.
#
# **Given the PMF of X:**
#
# Pr(K) = {0.2 for K = -2, -1, 0, 1, 2, 0 otherwise}
#
# **Applying the transformation Y = (X + 1), we add 1 to each value of
# X:**
#
# The range of X is {-2, -1, 0, 1, 2}, and when we add 1 to each value, we
# get the range of Y: {-1, 0, 1, 2, 3}.
#
# **Therefore, the range of Y is {-1, 0, 1, 2, 3}.**
#
# **2. Finding the PMF of Y:**
#
# To find the PMF of Y, we need to determine the probability for each
# value in the range of Y.
#
# **Given the PMF of X:**
#
# Pr(K) = {0.2 for K = -2, -1, 0, 1, 2, 0 otherwise}
#
# **Since Y = (X + 1), we can substitute each value of Y into the PMF of X
# to find the corresponding probability:**
#
# P(Y = -1) = Pr(X = -2) = 0.2
#
# P(Y = 0) = Pr(X = -1) = 0.2
#
# P(Y = 1) = Pr(X = 0) = 0.2
#
# P(Y = 2) = Pr(X = 1) = 0.2
#
# P(Y = 3) = Pr(X = 2) = 0.2
#
# **Therefore, the PMF of Y is as follows:**
#
# Pr(Y = -1) = 0.2
#
# Pr(Y = 0) = 0.2
#
# Pr(Y = 1) = 0.2
#
# Pr(Y = 2) = 0.2
#
# Pr(Y = 3) = 0.2
#
# Note: Since the PMF of X has a probability of 0 for any other value not
# listed, the PMF of Y will also have probabilities of 0 for any value not
# in the range of Y (-1, 0, 1, 2, 3).
#
# **2.Assuming X is a continuous random variable with PDF**
#
# <img src="attachment:media/image3.png" style="width:3.25833in;height:0.66667in" alt="img" />
#
# 1.  **Find EX and Var(X).**
#
# 2.  **Find *P*(*X* ≥ **<img src="attachment:media/image4.png" style="width:0.10833in;height:0.375in" alt="img" />**).**
#
# <img src="attachment:media/image5.png" style="width:7.26806in;height:2.21875in" />
#
# <img src="attachment:media/image6.png" style="width:7.26806in;height:2.93264in" />
#
# 1.  **If *X* is a continuous random variable with pdf **
#
# <img src="attachment:media/image7.png" style="width:1.75in;height:1.05in" alt="images" />
#
# <img src="attachment:media/image8.png" style="width:6.36458in;height:2.45833in" />
#
# 1.  **If *X*\~Uniform**<img src="attachment:media/image9.png" style="width:0.48333in;height:0.29167in" alt="img" />** and *Y* =
#     sin(*X*), then find *f<sub>Y</sub>*(*y*).**
#
# <img src="attachment:media/image10.png" style="width:7.26806in;height:4.78264in" />
#
# <img src="attachment:media/image11.png" style="width:5.97917in;height:1.65625in" />
#
# 1.  **If X is a random variable with CDF **
#
# <img src="attachment:media/image12.png" style="width:2.55in;height:0.81667in" alt="images" />
#
# 1.  **What kind of random variable is *X*: discrete, continuous, or
#     mixed?**
#
# 2.  **Find the PDF of *X*, f*X*(*x*).**
#
# 3.  **Find E(e<sup>X</sup>).**
#
# 4.  **Find P(*X* = 0\|X≤0.5).**
#
# <img src="attachment:media/image13.png" style="width:7.26806in;height:5.40903in" />
#
# <img src="attachment:media/image14.png" style="width:7.26806in;height:3.28264in" />
#
# **6.There are two random variables *X* and *Y* with joint PMF given in
# Table below**
#
# 1.  **Find *P*(*X*≤2, *Y*≤4).**
#
# 2.  **Find the marginal PMFs of *X* and *Y*.**
#
# 3.  **Find *P*(*Y* = 2\|*X* = 1).**
#
# 4.  **Are *X* and *Y* independent? **
#
# <img src="attachment:media/image15.png" style="width:4.09167in;height:0.95in" alt="images" />
#
# <img src="attachment:media/image16.png" style="width:6.64583in;height:5.78125in" />
#
# <img src="attachment:media/image17.png" style="width:6.89583in;height:3.44792in" />
#
# **6.A box containing 40 white shirts and 60 black shirts. If we choose
# 10 shirts (without replacement) at random, find the joint PMF of X and
# Y, where X is the number of white shirts and Y is the number of black
# shirts.**
#
# <img src="attachment:media/image18.png" style="width:6.47917in;height:2.15625in" />
#
# 1.  **If A and B are two jointly continuous random variables with joint
#     PDF**
#
# <img src="attachment:media/image19.png" style="width:3.48333in;height:0.625in" alt="images" />
#
# **a. Find fX(a) and fY(b).**
#
# **b. Are A and B independent of each other?**
#
# **c. Find the conditional PDF of A given B = b, fA\|B(a\|b).**
#
# **d. Find E\[A\|B = b\], for 0 ≤ y ≤ 1.**
#
# **e. Find Var(A\|B = b), for 0 ≤ y ≤ 1.**
#
# <img src="attachment:media/image20.png" style="width:6.875in;height:3.80208in" />
#
# 1.  **There are 100 men on a ship. If Xi is the ith man's weight on the
#     ship and Xi's are independent and identically distributed and EXi =
#     μ = 170 and σXi = σ = 30. Find the probability that the men's total
#     weight on the ship exceeds 18,000.**
#
# To find the probability that the total weight of the men on the ship
# exceeds 18,000, we can use the Central Limit Theorem (CLT) since we have
# a large sample size (100 men) and the weights are independent and
# identically distributed.
#
# According to the CLT, the sum of independent and identically distributed
# random variables approaches a normal distribution as the sample size
# increases.
#
# Let's denote the total weight of the men on the ship as W. The mean of
# the total weight can be calculated as E(W) = n \* μ, where n is the
# number of men (100) and μ is the mean weight of an individual (170).
#
# The standard deviation of the total weight can be calculated as σ(W) =
# sqrt(n) \* σ, where σ is the standard deviation of an individual's
# weight (30).
#
# **Therefore, for W \~ N(n \* μ, sqrt(n) \* σ), we can calculate the
# probability that the total weight exceeds 18,000 as follows:**
#
# P(W \> 18,000) = P((W - n \* μ) / (sqrt(n) \* σ) \> (18,000 - n \* μ) /
# (sqrt(n) \* σ))
#
# **Using the properties of the standard normal distribution, we can
# standardize the variable:**
#
# P(W \> 18,000) = P(Z \> (18,000 - n \* μ) / (sqrt(n) \* σ))
#
# **where Z is a standard normal random variable.**
#
# **Substituting the given values, we have:**
#
# P(W \> 18,000) = P(Z \> (18,000 - 100 \* 170) / (sqrt(100) \* 30))
#
# P(W \> 18,000) = P(Z \> (18,000 - 17,000) / (300))
#
# P(W \> 18,000) = P(Z \> 1 / 3)
#
# Using a standard normal distribution table or a calculator, we can find
# the probability associated with Z \> 1/3. This probability corresponds
# to the area under the standard normal curve to the right of 1/3.
#
# Therefore, the probability that the men's total weight on the ship
# exceeds 18,000 can be obtained by referring to a standard normal
# distribution table or using a calculator.
#
# 1.  **Let X1, X2, ……, X25 are independent and identically distributed.
#     And have the following PMF**
#
# **If Y = X1 + X2 + … + Xn, estimate P(4 ≤ Y ≤ 6) using central limit
# theorem.**
#
# To estimate P(4 ≤ Y ≤ 6) using the Central Limit Theorem (CLT), we need
# to apply the CLT to the sum of independent and identically distributed
# random variables X1, X2, ..., X25.
#
# Given that X1, X2, ..., X25 are independent and identically distributed,
# we can assume that they have a common mean (μ) and a common standard
# deviation (σ).
#
# According to the CLT, as the sample size (n) increases, the distribution
# of the sample mean approaches a normal distribution with a mean equal to
# the population mean (μ) and a standard deviation equal to the population
# standard deviation divided by the square root of the sample size
# (σ/sqrt(n)).
#
# In this case, since we are interested in the sum of 25 random variables
# (Y = X1 + X2 + ... + X25), we can consider Y as the sample mean of these
# 25 variables.
#
# Let's denote the mean of each individual random variable as μ and the
# standard deviation as σ. Since we have 25 variables, the mean of the sum
# (Y) will be n \* μ and the standard deviation will be sqrt(n) \* σ.
#
# **Therefore, for Y \~ N(n \* μ, sqrt(n) \* σ), we can estimate P(4 ≤ Y ≤
# 6) by calculating the corresponding probabilities using the standard
# normal distribution.**
#
# P(4 ≤ Y ≤ 6) = P((4 - n \* μ) / (sqrt(n) \* σ) ≤ Z ≤ (6 - n \* μ) /
# (sqrt(n) \* σ))
#
# **Using the properties of the standard normal distribution, we can
# standardize the variable:**
#
# P(4 ≤ Y ≤ 6) = P((4 - n \* μ) / (sqrt(n) \* σ) ≤ Z ≤ (6 - n \* μ) /
# (sqrt(n) \* σ))
#
# **where Z is a standard normal random variable.**
#
# **Substituting the given values, we have:**
#
# P(4 ≤ Y ≤ 6) = P((4 - 25 \* μ) / (sqrt(25) \* σ) ≤ Z ≤ (6 - 25 \* μ) /
# (sqrt(25) \* σ))
#
# P(4 ≤ Y ≤ 6) = P((4 - 25 \* μ) / (5 \* σ) ≤ Z ≤ (6 - 25 \* μ) / (5 \*
# σ))
#
# Using a standard normal distribution table or a calculator, we can find
# the probability associated with the range (4 - 25 \* μ) / (5 \* σ) ≤ Z ≤
# (6 - 25 \* μ) / (5 \* σ). This probability corresponds to the area under
# the standard normal curve between the standardized values (4 - 25 \* μ)
# / (5 \* σ) and (6 - 25 \* μ) / (5 \* σ).
#
# Note that the estimation using the CLT assumes that the sample size is
# large enough for the CLT to hold.
